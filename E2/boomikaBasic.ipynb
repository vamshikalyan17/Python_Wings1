# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 10
b = 20
c = a + b
print(c)
# Out:
# 30

# %%
a, b = 10, 20
a += b
a
# Out:
# 30

# %%
a = b = 10
print(a, b)
# Out:
# 10 10

# %%
x = 5
y = "Hello, World!"
x + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [7], line 3
#       1 x = 5
#       2 y = "Hello, World!"
# ----> 3 x + y
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = "Hello"
b = "World"
print(a + b)
# Out:
# HelloWorld

# %%
# This is a comment
#print("Boomika")

# %%
"""
the dag barks
this is a program
I am boomika
hello world
"""
# Out:
# '\nthe dag barks\nthis is a program\nI am boomika\nhello world\n'

# %%
vamshi = "Hello"
a = vamshi
type(a)
b = 10
type(b)
# Out:
# int

# %%
c = 10.0
type(c)
# Out:
# float

# %%
a = []
type(a)
# Out:
# list

# %%
a = ()
type(a)
# Out:
# tuple

# %%
a = {"name": "vamshi", "number": 4356}
type(a)
print(a)
# Out:
# {'name': 'vamshi', 'number': 4356}

# %%
a = {"vamshi", "kalyan"}
type(a)
# Out:
# set

# %%
print("Hello \"world\"")
# Out:
# Hello "world"

# %%
a = ["apple", "mango", "papaya"]
a, b, c = a
print(a, b, c)
# Out:
# apple mango papaya

# %%
a = 5

def boomika():
    global a,b
    a = b = 10
    print(a,b)

boomika()
a = 11
print(a)
print(b)
# Out:
# 10 10
# 11
# 10

# %%
boomika = b'abc'
for i in boomika:
    print(i)
# Out:
# 97
# 98
# 99

# %%
abc = bytearray("vamshi", "utf-8")
for i in abc:
    print(i)
# Out:
# 118
# 97
# 109
# 115
# 104
# 105

# %%
for i in range(len(abc)):
    print(abc[i])
# Out:
# 118
# 97
# 109
# 115
# 104
# 105

# %%
len(abc)
# Out:
# 6

# %%
for i in range(10, 4, -2):
    print("&"*i)
# Out:
# &&&&&&&&&&
# &&&&&&&&
# &&&&&&

# %%
for i in range(4, -1, -3):
    print(i)
# Out:
# 4
# 1

# %%
for i in range(0, 6, 1):
    print(i)
# Out:
# 0
# 2
# 4

# %%
for i in range(6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
