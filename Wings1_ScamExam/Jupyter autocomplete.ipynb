# %%
# !pip install jupyter_contrib_nbextensions

# %%
# !jupyter contrib nbextension install --user
# Out:
# [I 21:23:37 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 21:23:37 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 21:23:37 InstallContribNbextensionsApp] Installing C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\jupyter_contrib_nbextensions\nbextensions\addbefore -> addbefore
# [I 21:23:37 InstallContribNbextensionsApp] Making directory: C:\Users\USER\AppData\Roaming\jupyter\nbextensions\addbefore\
# [I 21:23:37 InstallContribNbextensionsApp] Copying: C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\jupyter_contrib_nbextensions\nbextensions\addbefore\addbefore.yaml -> C:\Users\USER\AppData\Roaming\jupyter\nbextensions\addbefore\addbefore.yaml
# ...

# %%
# !jt -t onedork

# %%
# !jt -t grade3
